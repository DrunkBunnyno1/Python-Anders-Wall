# %% [markdown]
# #### Labb 2
#
# - Letat på dett med .csv filer och försökt hitta hur man rensar, allt använder panda, jag får snygga till detta och sätta det i funktioner i alla fall.

# %%
import csv
import math
import matplotlib.pyplot as plt


def main_pokmon():

    def pokmon_pichu_pikachu():
        
        with open("C:\\Users\\waan2\\Documents\\Python-Anders-Wall\\Labs\\Labb_2_Maskin\\recorses\\datapoints.txt", "r") as file:
            pokemon_reed = file.read()
            
            # Spliting the file in chunks at new line
        pokemon_split = pokemon_reed.split("\n")
        return pokemon_split
    
    pokemon_split = pokmon_pichu_pikachu()
    

    def pichu_pikachu(pokemon_split):
        #Apending Pokemon Pichu and Pikachu to list depending on the last character
        # for index, pok in enumerate(pokemon_split[1][-1]):
        #     print(f"{index}: {pok}")
        pokemon_pika = []
        pokemon_pich = []
        pich = []
        pika = []
        for i in pokemon_split[0:151]:
           
            if i[-1] == "1":
                pokemon_pika.append(i)
            elif i[-1]== "0":
                pokemon_pich.append(i)
        # spliting line of characters to smaler chunk´s and appening them to list
        for i in pokemon_pich:
            pich.append(i.split(','))
        for i in pokemon_pika:
            pika.append(i.split(','))
        # Deliting unvanted varibuls in the list
        count1 = 0
        for i in pich:
            del pich[count1][2]
            del pika[count1][2]
            count1 += 1

        return pich, pika

    pich, pika = pichu_pikachu(pokemon_split)

    # for index, pok in enumerate(pika):
    #     print(f"{index}: {pok}")

    def x_y_axis(pich,pika):
        # Separating x and y axis 
        pich_x_axis = []
        pika_x_axis = []
        pich_y = []
        pika_y = []
        count2 = 0
        for i in pich:
            pich_x_axis.append(pich[count2][0])
            pika_x_axis.append(pika[count2][0])
            pich_y.append(pich[count2][1])
            pika_y.append(pika[count2][1])
            count2 +=1
            # Striping y axis from unvanted space    
        return pich_x_axis, pich_y, pika_x_axis, pika_y
    
    pich_x_axis, pich_y, pika_x_axis, pika_y = x_y_axis(pich, pika)

    # for index, pok in enumerate(pika_y_axis):
    #     print(f"{index}: {pok}")

    def strip(strip_one, strip_two):
        pich_y_axis = []
        pika_y_axis = []
        for i in strip_one:
            pika_y_axis.append(i.strip())
        for i in strip_two:
            pich_y_axis.append(i.strip())
        return pika_y_axis, pich_y_axis
    pika_y_axis, pich_y_axis = strip(pika_y, pich_y)

    # for index, pok in enumerate(pika_y_axis):
    #     print(f"{index}: {pok}")

    def test_data():
        test_point_x = []
        test_point_y = []
        #Read test data from .csv file and clean it from unvanted characters
        with open("C:\\Users\\waan2\\Documents\\Python-Anders-Wall\\Labs\\Labb_2_Maskin\\recorses\\testpoints.csv", "r") as file:
            pokemon_test_point = csv.reader(file, delimiter=" ")

            # Next loop over first line
            next(pokemon_test_point)
            # Append valu in second and third to two difrent list for x and y axis
            for i in pokemon_test_point:
                test_point_x.append(i[1])
                test_point_y.append(i[2])
            return test_point_x, test_point_y
    test_point_x, test_point_y = test_data()

    def clean_unvanted_decimal(clean):
        clean_test_point = []
        for i in clean:
            z = i.replace("(","") 
            r = z.replace(",","")
            s = r.replace(",","")
            t = s.replace(")","")
            clean_test_point.append(t)
        return clean_test_point
    
    clean_test_point_x = clean_unvanted_decimal(test_point_x) 
    clean_test_point_y = clean_unvanted_decimal(test_point_y)

    # for index, pok in enumerate(clean_test_point_x):
    #     print(f"{index}: {pok}")
    # for index, pok in enumerate(clean_test_point_y):
    #     print(f"{index}: {pok}")

    def pokemon_calculate(x_valu, y_valu, pokemon_x_valu, pokemon_y_valu):
        count_input = 0
        for input_valu in x_valu:
            distance = []
            count_pokemon = 0
            for pokemon_valu in pokemon_x_valu:
                distance.append(math.sqrt((float(x_valu[count_input]) - float(pokemon_x_valu[count_pokemon]))**2 + (float(y_valu[count_input]) - float(pokemon_y_valu[count_pokemon]))**2))
                #print(distance)
                count_pokemon += 1
            count_input += 1
        return distance
                    
    
    distance_test = pokemon_calculate(clean_test_point_x, clean_test_point_y, pich_x_axis, pich_y_axis)
    
    def user_input_distance():
        while True:
            while True:
                try:                    
                    user_x_axis = [float(input("Type ur x value: "))]
                    user_y_axis = [float(input("Type ur y valu: "))]
                    break
                except ValueError:
                    print("Input must be an integer or decimal number")
            if user_x_axis[0] <=0 or user_y_axis[0] <=0:
                print(f"Input must be a posetiv integer or decimal number, you'r x: {user_x_axis} and y: {user_y_axis}")
            else:
                break
        distance_user_pichu = pokemon_calculate(user_x_axis, user_y_axis, pich_x_axis, pich_y_axis)
        distance_user_pikachu = pokemon_calculate(user_x_axis, user_y_axis, pika_x_axis, pika_y_axis)

        return distance_user_pichu, distance_user_pikachu
    
    user_input_distance()
    # pichu_pikachu

        
    # for index, pok in enumerate(distance_test):
    #     print(f"{index}: {pok}")
    

main_pokmon()













#     pokemon_test_data()

#     def user_input():
#         print("WTF")
    

#     user_input()

#     def calculate_pokemon():
#         print("FFS")
    
#     calculate_pokemon()


# main_pokmon()


#["(width (cm)"]
#[" height (cm)"]
#[" label (0-pichu"]

#23.63591632187622', ' 36.46821490673444'
# Out:
# Input must be a posetiv integer or decimal number, you'r x: [-22.0] and y: [-23.0]
# Input must be a posetiv integer or decimal number, you'r x: [22.0] and y: [-22.0]
# [25.0]
# [25.0]
